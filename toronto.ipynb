# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ## Part 1

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 
import folium # map rendering library

# !conda install -c anaconda beautifulsoup4
from bs4 import BeautifulSoup as bs

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
wiki_page = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
html = wiki_page.content

# %%
page = bs(html, 'html.parser')
data = page.find_all("td")
# print(data)

for item in data:
    if item.a:
        item = item.a.unwrap()
#     print(item)
    
# page

# %%
rows = []
t_rows = page.table.find_all("tr")

for item in t_rows:
    t_row = []
    contents = item.contents
    for content in contents:
        try:
            t_row.append(content.contents[0].strip())
#             print(content.contents[0].strip())
        except:
            t_row.append(content.string.strip())
#             print(content.string)
#         print(t_row)
    rows.append(t_row)
# rows

# %%
t_data = pd.DataFrame(rows)
t_data.drop([0,2,4], axis = 1, inplace=True)
t_data.columns = t_data.iloc[0]
t_data.drop(0, axis=0, inplace=True)
t_data.reset_index(drop=True, inplace=True)
# t_data.head()

# %%
for ind in t_data.index:
#     print(ind)
    if t_data["Borough"][ind] == "Not assigned":
        t_data.drop(ind, axis=0, inplace=True)
#         print(ind)



# t_data.head()

# %%
for ind in t_data.index:
    if t_data["Neighbourhood"][ind] == "Not assigned":
        t_data["Neighbourhood"][ind] = t_data["Borough"][ind]
t_data.reset_index(drop=True, inplace=True)

# t_data.head()

# %%
for ind in t_data.index:
    try:
        ind + 1
        if t_data["Postcode"][ind] == t_data["Postcode"][ind+1] and t_data["Borough"][ind] == t_data["Borough"][ind+1]:
            t_data["Neighbourhood"][ind] = t_data["Neighbourhood"][ind] + ", " + t_data["Neighbourhood"][ind+1]
            t_data.drop(ind+1, axis=0, inplace=True)
    except:
        continue
        
t_data
# Out:
# 0   Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 5        M7A  Downtown Toronto
# 6        M9A      Queen's Park
# 7        M1B       Scarborough
# 9        M3B        North York
# 10       M4B         East York
# 12       M5B  Downtown Toronto
# 14       M6B        North York
# 15       M9B         Etobicoke
# 17       M9B         Etobicoke
# 19       M9B         Etobicoke
# 20       M1C       Scarborough
# 22       M1C       Scarborough
# 23       M3C        North York
# 25       M4C         East York
# 26       M5C  Downtown Toronto
# 27       M6C              York
# 28       M9C         Etobicoke
# 30       M9C         Etobicoke
# 32       M1E       Scarborough
# 34       M1E       Scarborough
# 35       M4E      East Toronto
# 36       M5E  Downtown Toronto
# 37       M6E              York
# 38       M1G       Scarborough
# 39       M4G         East York
# 40       M5G  Downtown Toronto
# 41       M6G  Downtown Toronto
# 42       M1H       Scarborough
# 43       M2H        North York
# 44       M3H        North York
# 46       M3H        North York
# 47       M4H         East York
# 48       M5H  Downtown Toronto
# 50       M5H  Downtown Toronto
# 51       M6H      West Toronto
# 53       M1J       Scarborough
# 54       M2J        North York
# 56       M2J        North York
# 57       M3J        North York
# 59       M4J         East York
# 60       M5J  Downtown Toronto
# 62       M5J  Downtown Toronto
# 63       M6J      West Toronto
# 65       M1K       Scarborough
# 67       M1K       Scarborough
# 68       M2K        North York
# 69       M3K        North York
# 71       M4K      East Toronto
# 73       M5K  Downtown Toronto
# 75       M6K      West Toronto
# 77       M6K      West Toronto
# 78       M1L       Scarborough
# 80       M1L       Scarborough
# 81       M2L        North York
# 83       M3L        North York
# 84       M4L      East Toronto
# 86       M5L  Downtown Toronto
# 88       M6L        North York
# 90       M6L        North York
# 91       M9L        North York
# 92       M1M       Scarborough
# 94       M1M       Scarborough
# 95       M2M        North York
# 97       M3M        North York
# 98       M4M      East Toronto
# 99       M5M        North York
# 101      M6M              York
# 103      M6M              York
# 105      M9M        North York
# 107      M1N       Scarborough
# 109      M2N        North York
# 110      M3N        North York
# 111      M4N   Central Toronto
# 112      M5N   Central Toronto
# 113      M6N              York
# 115      M9N              York
# 116      M1P       Scarborough
# 118      M1P       Scarborough
# 119      M2P        North York
# 120      M4P   Central Toronto
# 105                                   Emery, Humberlea
# 107                        Birch Cliff, Cliffside West
# 109                                   Willowdale South
# 110                                Downsview Northwest
# 111                                      Lawrence Park
# 112                                           Roselawn
# 113                      The Junction North, Runnymede
# 115                                             Weston
# 116               Dorset Park, Scarborough Town Centre
# 118                                    Wexford Heights
# 119                                    York Mills West
# 120                                   Davisville North
# 121                Forest Hill North, Forest Hill West
# 123                      High Park, The Junction South
# 125                                          Westmount
# 126                                  Maryvale, Wexford
# 128                                    Willowdale West
# 129                                 North Toronto West
# 130                           The Annex, North Midtown
# 132                                          Yorkville
# 133                             Parkdale, Roncesvalles
# 135              Canada Post Gateway Processing Centre
# 136            Kingsview Village, Martin Grove Gardens
# 138                     Richview Gardens, St. Phillips
# 140                                          Agincourt
# 141                                         Davisville
# 142                     Harbord, University of Toronto
# 144                                 Runnymede, Swansea
# 146                           Clarks Corners, Sullivan
# 148                                      Tam O'Shanter
# 149                        Moore Park, Summerhill East
# 151                             Chinatown, Grange Park
# 153                                  Kensington Market
# 154                   Agincourt North, L'Amoreaux East
# 156                             Milliken, Steeles East
# 158                          Deer Park, Forest Hill SE
# 160                              Rathnelly, South Hill
# 162                                    Summerhill West
# 163                            CN Tower, Bathurst Quay
# 165                  Island airport, Harbourfront West
# 167                    King and Spadina, Railway Lands
# 169                                      South Niagara
# 170                    Humber Bay Shores, Mimico South
# 172                                        New Toronto
# 173                   Albion Gardens, Beaumond Heights
# 175                              Humbergate, Jamestown
# 177                           Mount Olive, Silverstone
# 179                         South Steeles, Thistletown
# 181                                    L'Amoreaux West
# 182                                           Rosedale
# 183                    Stn A PO Boxes 25 The Esplanade
# 184                             Alderwood, Long Branch
# 186                                          Northwest
# 187                                        Upper Rouge
# 188                        Cabbagetown, St. James Town
# 190             First Canadian Place, Underground city
# 192                      The Kingsway, Montgomery Road
# 194                                     Old Mill North
# 195                               Church and Wellesley
# 196  Business Reply Mail Processing Centre 969 Eastern
# 197                       Humber Bay, King's Mill Park
# 199                Kingsway Park South East, Mimico NE
# 201                 Old Mill South, The Queensway East
# 203                    Royal York South East, Sunnylea
# 205                Kingsway Park South West, Mimico NW
# 207          The Queensway West, Royal York South West
# 209                                     South of Bloor

# %%
t_data.shape
# Out:
# (139, 3)

# %% [markdown]
# ## Part 2

# %%
coords = pd.read_csv('Geospatial_Coordinates.csv')
coords.sort_values(by=["Postal Code"], axis=0, ascending="true")
coords.head()

t_data.insert(3, column="Latitude", value=np.nan)
t_data.insert(4, column="Longitude", value=np.nan)

# t_data

# %%
for ind in t_data.index:
#     print(t_data['Postcode'][ind])
    for index in coords.index:
        if t_data["Postcode"][ind] == coords["Postal Code"][index]:
            t_data["Longitude"][ind] = coords["Longitude"][index]
            t_data["Latitude"][ind] = coords["Latitude"][index]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
t_data
# Out:
# 0   Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 5        M7A  Downtown Toronto
# 6        M9A      Queen's Park
# 7        M1B       Scarborough
# 9        M3B        North York
# 10       M4B         East York
# 12       M5B  Downtown Toronto
# 14       M6B        North York
# 15       M9B         Etobicoke
# 17       M9B         Etobicoke
# 19       M9B         Etobicoke
# 20       M1C       Scarborough
# 22       M1C       Scarborough
# 23       M3C        North York
# 25       M4C         East York
# 26       M5C  Downtown Toronto
# 27       M6C              York
# 28       M9C         Etobicoke
# 30       M9C         Etobicoke
# 32       M1E       Scarborough
# 34       M1E       Scarborough
# 35       M4E      East Toronto
# 36       M5E  Downtown Toronto
# 37       M6E              York
# 38       M1G       Scarborough
# 39       M4G         East York
# 40       M5G  Downtown Toronto
# 41       M6G  Downtown Toronto
#
Forest Hill North, Forest Hill West  43.696948 -79.411307
# 123                      High Park, The Junction South  43.661608 -79.464763
# 125                                          Westmount  43.696319 -79.532242
# 126                                  Maryvale, Wexford  43.750072 -79.295849
# 128                                    Willowdale West  43.782736 -79.442259
# 129                                 North Toronto West  43.715383 -79.405678
# 130                           The Annex, North Midtown  43.672710 -79.405678
# 132                                          Yorkville  43.672710 -79.405678
# 133                             Parkdale, Roncesvalles  43.648960 -79.456325
# 135              Canada Post Gateway Processing Centre  43.636966 -79.615819
# 136            Kingsview Village, Martin Grove Gardens  43.688905 -79.554724
# 138                     Richview Gardens, St. Phillips  43.688905 -79.554724
# 140                                          Agincourt  43.794200 -79.262029
# 141                                         Davisville  43.704324 -79.388790
# 142                     Harbord, University of Toronto  43.662696 -79.400049
# 144                                 Runnymede, Swansea  43.651571 -79.484450
# 146                           Clarks Corners, Sullivan  43.781638 -79.304302
# 148                                      Tam O'Shanter  43.781638 -79.304302
# 149                        Moore Park, Summerhill East  43.689574 -79.383160
# 151                             Chinatown, Grange Park  43.653206 -79.400049
# 153                                  Kensington Market  43.653206 -79.400049
# 154                   Agincourt North, L'Amoreaux East  43.815252 -79.284577
# 156                             Milliken, Steeles East  43.815252 -79.284577
# 158                          Deer Park, Forest Hill SE  43.686412 -79.400049
# 160                              Rathnelly, South Hill  43.686412 -79.400049
# 162                                    Summerhill West  43.686412 -79.400049
# 163                            CN Tower, Bathurst Quay  43.628947 -79.394420
# 165                  Island airport, Harbourfront West  43.628947 -79.394420
# 167                    King and Spadina, Railway Lands  43.628947 -79.394420
# 169                                      South Niagara  43.628947 -79.394420
# 170                    Humber Bay Shores, Mimico South  43.605647 -79.501321
# 172                                        New Toronto  43.605647 -79.501321
# 173                   Albion Gardens, Beaumond Heights  43.739416 -79.588437
# 175                              Humbergate, Jamestown  43.739416 -79.588437
# 177                           Mount Olive, Silverstone  43.739416 -79.588437
# 179                         South Steeles, Thistletown  43.739416 -79.588437
# 181                                    L'Amoreaux West  43.799525 -79.318389
# 182                                           Rosedale  43.679563 -79.377529
# 183                    Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 184                             Alderwood, Long Branch  43.602414 -79.543484
# 186                                          Northwest  43.706748 -79.594054
# 187                                        Upper Rouge  43.836125 -79.205636
# 188                        Cabbagetown, St. James Town  43.667967 -79.367675
# 190             First Canadian Place, Underground city  43.648429 -79.382280
# 192                      The Kingsway, Montgomery Road  43.653654 -79.506944
# 194                                     Old Mill North  43.653654 -79.506944
# 195                               Church and Wellesley  43.665860 -79.383160
# 196  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 197                       Humber Bay, King's Mill Park  43.636258 -79.498509
# 199                Kingsway Park South East, Mimico NE  43.636258 -79.498509
# 201                 Old Mill South, The Queensway East  43.636258 -79.498509
# 203                    Royal York South East, Sunnylea  43.636258 -79.498509
# 205                Kingsway Park South West, Mimico NW  43.628841 -79.520999
# 207          The Queensway West, Royal York South West  43.628841 -79.520999
# 209                                     South of Bloor  43.628841 -79.520999

# %% [markdown]
# ## Part 3

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(t_data['Latitude'], t_data['Longitude'], t_data['Borough'], t_data['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = '25OWNDKMSUODONJDHNAKG5S05EYYG4GVW2MGJ0GPHMNJBMSF'
CLIENT_SECRET = 'U510HBJBNEWLZRYBHYWXBK5BGU5H1DMW2HXX2ZX3WK35EZNM'
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 25OWNDKMSUODONJDHNAKG5S05EYYG4GVW2MGJ0GPHMNJBMSF
# CLIENT_SECRET:U510HBJBNEWLZRYBHYWXBK5BGU5H1DMW2HXX2ZX3WK35EZNM
